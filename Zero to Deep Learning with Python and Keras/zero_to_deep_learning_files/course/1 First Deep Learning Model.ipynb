# %% [markdown]
# # First Deep Learning Model
#
# Hello, world of people

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from sklearn.datasets.samples_generator import make_circles

# %%
X, y = make_circles(n_samples=1000,
                    noise=0.1,
                    factor=0.2,
                    random_state=0)

# %%
X
# Out:
# array([[ 0.24265541,  0.0383196 ],
#        [ 0.04433036, -0.05667334],
#        [-0.78677748, -0.75718576],
#        ...,
#        [ 0.0161236 , -0.00548034],
#        [ 0.20624715,  0.09769677],
#        [-0.19186631,  0.08916672]])

# %%
X.shape
# Out:
# (1000, 2)

# %%
plt.figure(figsize=(5, 5))
plt.plot(X[y==0, 0], X[y==0, 1], 'ob', alpha=0.5)
plt.plot(X[y==1, 0], X[y==1, 1], 'xr', alpha=0.5)
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.legend(['0', '1'])
plt.title("Blue circles and Red crosses")
# Out:
# Text(0.5, 1.0, 'Blue circles and Red crosses')

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()

# %%
model.add(Dense(4, input_shape=(2,), activation='tanh'))

# %%
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(SGD(lr=0.5), 'binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(X, y, epochs=20)
# Out:
# Epoch 1/20
# 1000/1000 [==============================] - 1s 905us/step - loss: 0.6888 - acc: 0.6180
# Epoch 2/20
# 1000/1000 [==============================] - 0s 108us/step - loss: 0.6486 - acc: 0.6940
# Epoch 3/20
# 1000/1000 [==============================] - 0s 111us/step - loss: 0.5901 - acc: 0.7680
# Epoch 4/20
# 1000/1000 [==============================] - 0s 107us/step - loss: 0.5027 - acc: 0.8430
# Epoch 5/20
# 1000/1000 [==============================] - 0s 94us/step - loss: 0.4284 - acc: 0.8500
# Epoch 6/20
# 1000/1000 [==============================] - 0s 98us/step - loss: 0.3750 - acc: 0.8690
# Epoch 7/20
# 1000/1000 [==============================] - 0s 97us/step - loss: 0.3112 - acc: 0.8870
# Epoch 8/20
# 1000/1000 [==============================] - 0s 97us/step - loss: 0.2367 - acc: 0.9420
# Epoch 9/20
# 1000/1000 [==============================] - 0s 95us/step - loss: 0.1723 - acc: 0.9920
# Epoch 10/20
# 1000/1000 [==============================] - 0s 105us/step - loss: 0.1301 - acc: 0.9990
# Epoch 11/20
# 1000/1000 [==============================] - 0s 102us/step - loss: 0.1027 - acc: 1.0000
# Epoch 12/20
# 1000/1000 [==============================] - 0s 96us/step - loss: 0.0847 - acc: 1.0000
# Epoch 13/20
# 1000/1000 [==============================] - 0s 99us/step - loss: 0.0719 - acc: 1.0000
# Epoch 14/20
# 1000/1000 [==============================] - 0s 94us/step - loss: 0.0624 - acc: 1.0000
# Epoch 15/20
# 1000/1000 [==============================] - 0s 109us/step - loss: 0.0551 - acc: 1.0000
# Epoch 16/20
# 1000/1000 [==============================] - 0s 95us/step - loss: 0.0493 - acc: 1.0000
# Epoch 17/20
# 1000/1000 [==============================] - 0s 98us/step - loss: 0.0447 - acc: 1.0000
# Epoch 18/20
# 1000/1000 [==============================] - 0s 96us/step - loss: 0.0409 - acc: 1.0000
# Epoch 19/20
# 1000/1000 [==============================] - 0s 114us/step - loss: 0.0377 - acc: 1.0000
# Epoch 20/20
# 1000/1000 [==============================] - 0s 122us/step - loss: 0.0350 - acc: 1.0000

# %%
hticks = np.linspace(-1.5, 1.5, 101)
vticks = np.linspace(-1.5, 1.5, 101)
aa, bb = np.meshgrid(hticks, vticks)
ab = np.c_[aa.ravel(), bb.ravel()]
c = model.predict(ab)
cc = c.reshape(aa.shape)

# %%
plt.figure(figsize=(5, 5))
plt.contourf(aa, bb, cc, cmap='bwr', alpha=0.2)
plt.plot(X[y==0, 0], X[y==0, 1], 'ob', alpha=0.5)
plt.plot(X[y==1, 0], X[y==1, 1], 'xr', alpha=0.5)
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.legend(['0', '1'])
plt.title("Blue circles and Red crosses")
# Out:
# Text(0.5, 1.0, 'Blue circles and Red crosses')
