# %% [markdown]
# # First Deep Learning Model

# %%
import numpy as np
# %matplotlib inline
import matplotlib.pyplot as plt

# %%
from sklearn.datasets.samples_generator import make_circles

# %%
X, y = make_circles(n_samples=1000,
                    noise=0.1,
                    factor=0.2,
                    random_state=0)

# %%
X
# Out:
# array([[ 0.24265541,  0.0383196 ],
#        [ 0.04433036, -0.05667334],
#        [-0.78677748, -0.75718576],
#        ...,
#        [ 0.0161236 , -0.00548034],
#        [ 0.20624715,  0.09769677],
#        [-0.19186631,  0.08916672]])

# %%
X.shape
# Out:
# (1000, 2)

# %%
plt.figure(figsize=(5, 5))
plt.plot(X[y==0, 0], X[y==0, 1], 'ob', alpha=0.5)
plt.plot(X[y==1, 0], X[y==1, 1], 'xr', alpha=0.5)
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.legend(['0', '1'])
plt.title("Blue circles and Red crosses")
# Out:
# Text(0.5, 1.0, 'Blue circles and Red crosses')

# %%
from keras.models import Sequential
from keras.layers import Dense
from keras.optimizers import SGD
# Out:
# Using TensorFlow backend.

# %%
model = Sequential()

# %%
model.add(Dense(4, input_shape=(2,), activation='tanh'))
# Out:
# WARNING:tensorflow:From /Users/juanpablo/.pyenv/versions/3.7.7/envs/ztdl/lib/python3.7/site-packages/tensorflow/python/framework/op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.

# %%
model.add(Dense(1, activation='sigmoid'))

# %%
model.compile(SGD(lr=0.5), 'binary_crossentropy', metrics=['accuracy'])

# %%
model.fit(X, y, epochs=20)
# Out:
# WARNING:tensorflow:From /Users/juanpablo/.pyenv/versions/3.7.7/envs/ztdl/lib/python3.7/site-packages/tensorflow/python/ops/math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Epoch 1/20
# 1000/1000 [==============================] - 0s 266us/step - loss: 0.6875 - acc: 0.5710
# Epoch 2/20
# 1000/1000 [==============================] - 0s 76us/step - loss: 0.6311 - acc: 0.7300
# Epoch 3/20
# 1000/1000 [==============================] - 0s 65us/step - loss: 0.5300 - acc: 0.8300
# Epoch 4/20
# 1000/1000 [==============================] - 0s 85us/step - loss: 0.4512 - acc: 0.8590
# Epoch 5/20
# 1000/1000 [==============================] - 0s 75us/step - loss: 0.4018 - acc: 0.8630
# Epoch 6/20
# 1000/1000 [==============================] - 0s 71us/step - loss: 0.3756 - acc: 0.8690
# Epoch 7/20
# 1000/1000 [==============================] - 0s 67us/step - loss: 0.3542 - acc: 0.8730
# Epoch 8/20
# 1000/1000 [==============================] - 0s 72us/step - loss: 0.3350 - acc: 0.8720
# Epoch 9/20
# 1000/1000 [==============================] - 0s 74us/step - loss: 0.3180 - acc: 0.8790
# Epoch 10/20
# 1000/1000 [==============================] - 0s 68us/step - loss: 0.2739 - acc: 0.8990
# Epoch 11/20
# 1000/1000 [==============================] - 0s 64us/step - loss: 0.2089 - acc: 0.9350
# Epoch 12/20
# 1000/1000 [==============================] - 0s 66us/step - loss: 0.1549 - acc: 0.9840
# Epoch 13/20
# 1000/1000 [==============================] - 0s 66us/step - loss: 0.1213 - acc: 0.9980
# Epoch 14/20
# 1000/1000 [==============================] - 0s 84us/step - loss: 0.0990 - acc: 0.9980
# Epoch 15/20
# 1000/1000 [==============================] - 0s 66us/step - loss: 0.0841 - acc: 0.9990
# Epoch 16/20
# 1000/1000 [==============================] - 0s 67us/step - loss: 0.0738 - acc: 0.9990
# Epoch 17/20
# 1000/1000 [==============================] - 0s 63us/step - loss: 0.0656 - acc: 1.0000
# Epoch 18/20
# 1000/1000 [==============================] - 0s 68us/step - loss: 0.0592 - acc: 1.0000
# Epoch 19/20
# 1000/1000 [==============================] - 0s 81us/step - loss: 0.0540 - acc: 1.0000
# Epoch 20/20
# 1000/1000 [==============================] - 0s 67us/step - loss: 0.0497 - acc: 0.9990

# %%
hticks = np.linspace(-1.5, 1.5, 101)
vticks = np.linspace(-1.5, 1.5, 101)
aa, bb = np.meshgrid(hticks, vticks)
ab = np.c_[aa.ravel(), bb.ravel()]
c = model.predict(ab)
cc = c.reshape(aa.shape)

# %%
plt.figure(figsize=(5, 5))
plt.contourf(aa, bb, cc, cmap='bwr', alpha=0.2)
plt.plot(X[y==0, 0], X[y==0, 1], 'ob', alpha=0.5)
plt.plot(X[y==1, 0], X[y==1, 1], 'xr', alpha=0.5)
plt.xlim(-1.5, 1.5)
plt.ylim(-1.5, 1.5)
plt.legend(['0', '1'])
plt.title("Blue circles and Red crosses")
# Out:
# Text(0.5, 1.0, 'Blue circles and Red crosses')
